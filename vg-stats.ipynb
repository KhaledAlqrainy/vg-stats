# %% [markdown]
# # Vg Scale
#
# ## Video Games dataset
#
# ## Author : Khaled Alqrainy
#
# ## Date : 25-10-2021

# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('./vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Which company is the most common video game publisher?

# %%
most_common_publisher=df.Publisher.mode()[0]
most_common_publisher
# Out:
# 'Electronic Arts'

# %% [markdown]
# ## What’s the most common platform?

# %%
most_common_platform=df.Platform.mode()[0]
most_common_platform
# Out:
# 'DS'

# %% [markdown]
# ## What about the most common genre?

# %%
most_common_genre=df.Genre.mode()[0]
most_common_genre
# Out:
# 'Action'

# %% [markdown]
# ## What are the top 20 highest grossing games?

# %%
top_twenty_highest_grossing_games=df[['Name', 'Global_Sales']].head(20)
top_twenty_highest_grossing_games
# Out:
#                                             Name  Global_Sales
# 0                                     Wii Sports         82.74
# 1                              Super Mario Bros.         40.24
# 2                                 Mario Kart Wii         35.82
# 3                              Wii Sports Resort         33.00
# 4                       Pokemon Red/Pokemon Blue         31.37
# 5                                         Tetris         30.26
# 6                          New Super Mario Bros.         30.01
# 7                                       Wii Play         29.02
# 8                      New Super Mario Bros. Wii         28.62
# 9                                      Duck Hunt         28.31
# 10                                    Nintendogs         24.76
# 11                                 Mario Kart DS         23.42
# 12                   Pokemon Gold/Pokemon Silver         23.10
# 13                                       Wii Fit         22.72
# ...

# %% [markdown]
# ## For North American video game sales, what’s the median?

# %%
north_american_median_sales=df.NA_Sales.median()
north_american_median_sales
# Out:
# 0.08

# %% [markdown]
# * Provide a secondary output showing ten games surrounding the median sales output
#
#     * assume that games with same median value are sorted in descending order

# %%
secondary_median = df[ df["NA_Sales"] == north_american_median_sales]
ten_median_na_seller_names =secondary_median.head(10)["Name"]
ten_median_na_seller_names
# Out:
# 446                                     Dragon Warrior IV
# 497           World Soccer Winning Eleven 7 International
# 1617                               Farming Simulator 2015
# 1926                            Pro Evolution Soccer 2008
# 2067    Winning Eleven: Pro Evolution Soccer 2007 (All...
# 2373                             Phantasy Star Portable 2
# 2579                                 The Sims 2: Castaway
# 3186                                       SingStar Queen
# 3503                                           Top Spin 3
# 3703                 Sonic & All-Stars Racing Transformed
# Name: Name, dtype: object

# %% [markdown]
# ## For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
ten_median_na_seller_names=(df['NA_Sales'].max()-df['NA_Sales'].mean()) /df['NA_Sales'].std()
ten_median_na_seller_names
# Out:
# 50.47898767479108

# %% [markdown]
# ## The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
avg_global = df.Global_Sales.mean() 
avg_global
# Out:
# 0.5374406555006628

# %%
avg_wii=df[(df['Platform']=='Wii') ].Global_Sales.mean() 
avg_wii
# Out:
# 0.6994037735849057

# %% [markdown]
# ## Come up with 3 more questions that can be answered with this data set.

# %% [markdown]
# ## what is the last 10 ranks ?

# %%
last_10=df.tail(10)
last_10
# Out:
#         Rank                                               Name Platform  \
# 16588  16591                                   Mega Brain Boost       DS
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
# 16590  16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...      PSP
# 16591  16594                                Myst IV: Revelation       PC
# 16592  16595                                           Plushees       DS
# 16593  16596                 Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                      Men in Black II: Alien Escape       GC
# 16595  16598   SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                         Know How 2       DS
# 16597  16600                                   Spirits & Spells      GBA
#
#          Year         Genre              Publisher  NA_Sales  EU_Sales  \
# 16588  2008.0        Puzzle  Majesco Entertainment      0.01      0.00
# ...

# %% [markdown]
# ## Sort the games by year.

# %%
sort_by_year=df.sort_values(by=['Year'])
sort_by_year
# Out:
#         Rank                         Name Platform    Year         Genre  \
# 6896    6898                     Checkers     2600  1980.0          Misc
# 2669    2671                       Boxing     2600  1980.0      Fighting
# 5366    5368                      Freeway     2600  1980.0        Action
# 1969    1971                     Defender     2600  1980.0          Misc
# 1766    1768                      Kaboom!     2600  1980.0          Misc
# ...      ...                          ...      ...     ...           ...
# 16307  16310                Freaky Flyers       GC     NaN        Racing
# 16327  16330                    Inversion       PC     NaN       Shooter
# 16366  16369  Hakuouki: Shinsengumi Kitan      PS3     NaN     Adventure
# 16427  16430                 Virtua Quest       GC     NaN  Role-Playing
# 16493  16496                   The Smurfs      3DS     NaN        Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %% [markdown]
# ## What is the games in PS2 platform ?

# %%
ps2_platform = df[df['Platform']=='PS2']
ps2_platform
# Out:
#         Rank                                              Name Platform  \
# 17        18                     Grand Theft Auto: San Andreas      PS2
# 24        25                       Grand Theft Auto: Vice City      PS2
# 28        29                            Gran Turismo 3: A-Spec      PS2
# 38        39                              Grand Theft Auto III      PS2
# 47        48                                    Gran Turismo 4      PS2
# ...      ...                                               ...      ...
# 16559  16562      Sugar + Spice! Anoko no Suteki na Nanimokamo      PS2
# 16561  16564                                    Kanokon: Esuii      PS2
# 16572  16575                  Scarlett: Nichijou no Kyoukaisen      PS2
# 16580  16583                                         Real Rode      PS2
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
#
#          Year      Genre                    Publisher  NA_Sales  EU_Sales  \
# ...

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

    assert_equal(most_common_publisher, 'Electronic Arts')
    assert_equal(most_common_platform, 'DS')
    assert_equal(most_common_genre, 'Action')
    assert_equal(top_twenty_highest_grossing_games.iloc[0].Name, 'Wii Sports')
    assert_equal(top_twenty_highest_grossing_games.iloc[19].Name, 'Brain Age: Train Your Brain in Minutes a Day')
    assert_equal(north_american_median_sales, 0.08)
    assert_equal(ten_median_na_seller_names, 50.47898767479108)
    assert_equal(avg_global, 0.5374406555006628)
    assert_equal(avg_wii, 0.6994037735849057)
    assert_equal(last_10.iloc[0].Rank,16591)
    assert_equal(ps2_platform.iloc[0].Name,'Grand Theft Auto: San Andreas')
    assert_equal(last_10, 0.6994037735849057)
    
    print("Success!")

test()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_30294/4215714931.py in <module>
#      19     print("Success!")
#      20
# ---> 21 test()
#
# /tmp/ipykernel_30294/4215714931.py in test()
#      15     assert_equal(last_10.iloc[0].Rank,16591)
#      16     assert_equal(ps2_platform.iloc[0].Name,'Grand Theft Auto: San Andreas')
# ---> 17     assert_equal(last_10, 0.6994037735849057)
#      18
#      19     print("Success!")
#
# /tmp/ipykernel_30294/4215714931.py in assert_equal(actual, expected)
#       2
#       3     def assert_equal(actual,expected):
# ----> 4         assert actual == expected, f"Expected {expected} but got {actual}"
#       5
#       6     assert_equal(most_common_publisher, 'Electronic Arts')
#
# ~/401_python/vg-stats/.venv/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
# ...
